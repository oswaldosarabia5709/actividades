# %%
    #Celda 1
    #DECLARACION DE VARIABLES.
    edad = 25

# %%
    #celda 2
    #NumBoleta
    Boleta = 2020301192

# %%
     #celda 3
     #Nombre de usuario
     Nombre = "oswaldo sarabia "

# %%
     # Celda 4
     #Tipo de variable
     type(edad)
# Out:
# int

# %%
     # celda 5
     #Tipo de variable
     type(Boleta)
# Out:
# int

# %%
     # celda 6
     #Tipo de variable
     type(Nombre)

# %%
    # celda 7
    #Impresion de datos
    a = 9
    b = 15
    c = a+b
    print(a,b,c)
# Out:
# 9 15 24

# %%
    # celda 8
    #Impresion de datos
    print("la suma de ", a," + ", b," es: ",c)
# Out:
# la suma de  9  +  15  es:  24

# %%
    #celda 9
    #Impresion de datos
    print("la suma de " + str(a) + "+" + str(b) + " es: " + str(c))
# Out:
# la suma de 9+15 es: 24

# %%
    # celda 10
    # Implementación del exponente
    a = 5
    print(a**2)
# Out:
# 25

# %%
   # celda 11
   # Implementación de modulo
   a = 7
   print(a%2)
# Out:
# 1

# %%
    # celda 12
    # Implementación de division entera
    a = 7
    print(a//2)
# Out:
# 3

# %%
     # celda 13
     #  división 
     a = 7
     b = 2
     print(a/b)
# Out:
# 3.5

# %%
    # celda 14
    # Multiplicación
    a = 7
    b = 2
    print(7/2)
# Out:
# 3.5

# %%
# celda 15
#  Resta
print(a - b)
# Out:
# 5

# %%
# celda 16
# Implementación suma
print(a + b)
# Out:
# 9

# %%
Nombre = input("Digite su nombre: ")

print(type(Nombre))

Edad = input("Digite  su edad: ")

print(type(Edad))

# %%
ambiando la variable edad a tipo numérico
Edad = int(input("Introduzca su edad: "))

print(type(Edad))
