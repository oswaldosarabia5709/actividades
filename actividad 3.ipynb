# %%
cal = float(input("Digite su  calificacion final:"))
if cal < 6:
	print("Reprobado");
	print("Necesitas esforzarte más")

print("Fin del programa")

# %%
cal = float(input("Digite su calificación:"))

if cal < 6:
	print("Reprobado")
else:
	print("Aprobado")

print("Fin del programa")
# Out:
# Digite su calificación:9
# Aprobado
# Fin del programa

# %%
cal = float(input("Digite su  calificación: "))
if cal < 6:
	print("Reprobado")
elif cal >= 8.5:
	print("Felicidades has aprobado")
else:
	print("Aprobado")
# Out:
# Introduce una calificación: 9
# Felicidades has aprobado

# %%
a = input("presiona una tecla: ")

if a=='a' or a=='e' or a=='i' or a=='o' or a=='u':
	print("Es una vocal")
else:
	print(" la letra es una consonante ")
# Out:
# presiona una tecla: l
#  la letra es una consonante
